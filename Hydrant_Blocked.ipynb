# %% [markdown]
# <a href="https://colab.research.google.com/github/UmarAzamQureshi/Hydrant_Blockage_Detection/blob/main/Hydrant_Blocked.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics opencv-python-headless pandas torch torchvision timm
# Out:
# Requirement already satisfied: ultralytics in /usr/local/lib/python3.12/dist-packages (8.3.203)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.12/dist-packages (4.12.0.88)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.8.0+cu126)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (0.23.0+cu126)
# Requirement already satisfied: timm in /usr/local/lib/python3.12/dist-packages (1.0.19)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (4.12.0.88)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.16.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: polars in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.25.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.17)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.4.0)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (from timm) (0.35.0)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.12/dist-packages (from timm) (0.6.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2025.8.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm) (4.67.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm) (1.1.10)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.2)

# %%
import cv2
import numpy as np
import os
from ultralytics import YOLO

# ---------------- Config ----------------
INPUT_FOLDER = "/content/hydrant_pano_images"
OUTPUT_FOLDER = "/content/result_out"
DEBUG_FOLDER = "/content/result_debug"

COVER_FRAC = 0.25          # % hydrant covered by car
FOREGROUND_Y_MARGIN = 10   # pixels, car centroid must be below hydrant centroid

# Class IDs (⚠️ adjust these to your trained model’s IDs)
HYDRANT_CLASS = 10   # change if hydrant is not class 0
CAR_CLASS = 2       # change if car is not class 1

os.makedirs(OUTPUT_FOLDER, exist_ok=True)
os.makedirs(DEBUG_FOLDER, exist_ok=True)

# ---------------- Utils ----------------
def get_box_and_mask(result, class_id):
    """Extract bounding boxes & masks for a given class_id."""
    objects = []
    if result.masks is not None:
        masks = result.masks.data.cpu().numpy().astype(bool)
    else:
        masks = [None] * len(result.boxes)

    for i, box in enumerate(result.boxes):
        cls = int(box.cls)
        if cls != class_id:
            continue
        x1, y1, x2, y2 = map(int, box.xyxy[0].cpu().numpy())
        centroid = ((y1 + y2) // 2, (x1 + x2) // 2)
        mask = masks[i] if masks[i] is not None else None
        objects.append({
            "box": (x1, y1, x2, y2),
            "mask": mask,
            "centroid": centroid
        })
    return objects


def hydrant_blocked(hydrants, cars, use_masks=True, cover_thresh=0.15, horiz_thresh=0.3, prox_thresh=30):
    results = [False] * len(hydrants)

    for hi, h in enumerate(hydrants):
        hx1, hy1, hx2, hy2 = h["box"]
        h_w, h_h = hx2 - hx1, hy2 - hy1
        h_cy = (hy1 + hy2) / 2

        # Expand hydrant region to be tolerant
        pad = 20
        hx1e, hy1e, hx2e, hy2e = hx1-pad, hy1-pad, hx2+pad, hy2+pad

        for ci, c in enumerate(cars):
            cx1, cy1, cx2, cy2 = c["box"]

            blocked = False
            overlap_ratio = 0.0
            horiz_frac = 0.0
            horiz_gap = 9999
            vertical_ok = cy2 >= h_cy

            if use_masks and h.get("mask") is not None and c.get("mask") is not None:
                # mask overlap
                h_mask = h["mask"].astype(np.uint8)
                c_mask = c["mask"].astype(np.uint8)
                inter = cv2.bitwise_and(h_mask, c_mask)
                overlap_ratio = inter.sum() / (h_mask.sum() + 1e-6)
                if overlap_ratio >= cover_thresh:
                    blocked = True

            # Fallback: bbox overlap
            if not blocked:
                overlap_w = max(0, min(hx2e, cx2) - max(hx1e, cx1))
                horiz_frac = overlap_w / (h_w + 1e-6)
                horiz_gap = min(abs(cx1 - hx2e), abs(hx1e - cx2))
                if (horiz_frac >= horiz_thresh and vertical_ok) or (horiz_gap <= prox_thresh and vertical_ok):
                    blocked = True

            # 🔎 Debug print
            print(f"\nHydrant {hi} vs Car {ci}:")
            print(f"  Hydrant box: {h['box']}")
            print(f"  Car box:     {c['box']}")
            print(f"  horiz_frac={horiz_frac:.2f}, vertical_ok={vertical_ok}, prox_gap={horiz_gap}")
            print(f"  overlap_ratio={overlap_ratio:.2f}")

            if blocked:
                results[hi] = True
                break

    return results


def draw_overlay(img, hydrants, cars, blocked_status):
    """Draw results on image."""
    out = img.copy()

    # cars
    for c in cars:
        x1, y1, x2, y2 = c["box"]
        cv2.rectangle(out, (x1, y1), (x2, y2), (0,255,0), 2)
        cv2.putText(out, "Car", (x1, y1-5), cv2.FONT_HERSHEY_SIMPLEX,
                    0.5, (0,255,0), 2)

    # hydrants
    for idx, (h, blocked) in enumerate(zip(hydrants, blocked_status)):
        x1, y1, x2, y2 = h["box"]
        color = (0,0,255) if blocked else (255,0,0)
        label = f"Hydrant {idx} BLOCKED" if blocked else f"Hydrant {idx} CLEAR"
        cv2.rectangle(out, (x1, y1), (x2, y2), color, 2)
        cv2.putText(out, label, (x1, y1-5), cv2.FONT_HERSHEY_SIMPLEX,
                    0.5, color, 2)

    return out


def draw_debug(img, hydrants, cars):
    """Draw hydrants (blue) and cars (red) for debugging."""
    debug_img = img.copy()
    for h in hydrants:
        x1, y1, x2, y2 = h["box"]
        cv2.rectangle(debug_img, (x1, y1), (x2, y2), (255, 0, 0), 2)  # blue = hydrant
    for c in cars:
        x1, y1, x2, y2 = c["box"]
        cv2.rectangle(debug_img, (x1, y1), (x2, y2), (0, 0, 255), 2)  # red = car
    return debug_img


# ---------------- Main ----------------
def process_image(model, img_path):
    img = cv2.imread(img_path)
    if img is None:
        raise ValueError(f"Could not load {img_path}")

    results = model.predict(img, verbose=False)[0]

    hydrants = get_box_and_mask(results, HYDRANT_CLASS)
    cars = get_box_and_mask(results, CAR_CLASS)

    blocked_status = hydrant_blocked(hydrants, cars)

    # Overlay + debug
    out = draw_overlay(img, hydrants, cars, blocked_status)
    debug_img = draw_debug(img, hydrants, cars)

    return out, debug_img, blocked_status


if __name__ == "__main__":
    # 🔧 load your trained model
    model = YOLO("yolov8s.pt")   # change path if needed

    for img_file in os.listdir(INPUT_FOLDER):
        if not img_file.lower().endswith((".jpg", ".png", ".jpeg")):
            continue

        img_path = os.path.join(INPUT_FOLDER, img_file)
        out, debug_img, status = process_image(model, img_path)

        blocked_ids = [i for i, b in enumerate(status) if b]
        if blocked_ids:
            print(f"🚨 Blocked: {img_file} — hydrants {blocked_ids}")
        else:
            print(f"✅ Clear: {img_file}")

        # Save overlays
        out_path = os.path.join(OUTPUT_FOLDER, img_file)
        debug_path = os.path.join(DEBUG_FOLDER, "debug_" + img_file)
        cv2.imwrite(out_path, out)
        cv2.imwrite(debug_path, debug_img)
# Out:
# ✅ Clear: 25.png
# ✅ Clear: 7.png
# ✅ Clear: 5.png
#
# Hydrant 0 vs Car 0:
#   Hydrant box: (983, 559, 1058, 712)
#   Car box:     (0, 304, 398, 486)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=565
#   overlap_ratio=0.00
#
# Hydrant 0 vs Car 1:
#   Hydrant box: (983, 559, 1058, 712)
#   Car box:     (314, 295, 518, 396)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=445
#   overlap_ratio=0.00
#
# Hydrant 0 vs Car 2:
#   Hydrant box: (983, 559, 1058, 712)
#   Car box:     (725, 266, 811, 326)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=152
#   overlap_ratio=0.00
#
# Hydrant 0 vs Car 3:
#   Hydrant box: (983, 559, 1058, 712)
#   Car box:     (462, 275, 567, 349)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=396
#   overlap_ratio=0.00
#
# Hydrant 0 vs Car 4:
#   Hydrant box: (983, 559, 1058, 712)
#   Car box:     (583, 269, 629, 323)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=334
#   overlap_ratio=0.00
#
# Hydrant 0 vs Car 5:
#   Hydrant box: (983, 559, 1058, 712)
#   Car box:     (585, 269, 659, 310)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=304
#   overlap_ratio=0.00
#
# Hydrant 0 vs Car 6:
#   Hydrant box: (983, 559, 1058, 712)
#   Car box:     (542, 270, 594, 342)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=369
#   overlap_ratio=0.00
#
# Hydrant 0 vs Car 7:
#   Hydrant box: (983, 559, 1058, 712)
#   Car box:     (466, 269, 598, 347)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=365
#   overlap_ratio=0.00
#
# Hydrant 0 vs Car 8:
#   Hydrant box: (983, 559, 1058, 712)
#   Car box:     (678, 245, 720, 278)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=243
#   overlap_ratio=0.00
#
# Hydrant 0 vs Car 9:
#   Hydrant box: (983, 559, 1058, 712)
#   Car box:     (723, 246, 766, 267)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=197
#   overlap_ratio=0.00
# ✅ Clear: 15.png
#
# Hydrant 0 vs Car 0:
#   Hydrant box: (1102, 541, 1126, 600)
#   Car box:     (129, 493, 297, 619)
#   horiz_frac=0.00, vertical_ok=True, prox_gap=785
#   overlap_ratio=0.00
#
# Hydrant 0 vs Car 1:
#   Hydrant box: (1102, 541, 1126, 600)
#   Car box:     (1655, 498, 1787, 589)
#   horiz_frac=0.00, vertical_ok=True, prox_gap=509
#   overlap_ratio=0.00
#
# Hydrant 0 vs Car 2:
#   Hydrant box: (1102, 541, 1126, 600)
#   Car box:     (481, 505, 591, 569)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=491
#   overlap_ratio=0.00
#
# Hydrant 0 vs Car 3:
#   Hydrant box: (1102, 541, 1126, 600)
#   Car box:     (1477, 471, 1541, 518)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=331
#   overlap_ratio=0.00
#
# Hydrant 0 vs Car 4:
#   Hydrant box: (1102, 541, 1126, 600)
#   Car box:     (1529, 470, 1577, 500)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=383
#   overlap_ratio=0.00
#
# Hydrant 0 vs Car 5:
#   Hydrant box: (1102, 541, 1126, 600)
#   Car box:     (362, 488, 416, 513)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=666
#   overlap_ratio=0.00
#
# Hydrant 0 vs Car 6:
#   Hydrant box: (1102, 541, 1126, 600)
#   Car box:     (331, 478, 370, 506)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=712
#   overlap_ratio=0.00
#
# Hydrant 0 vs Car 7:
#   Hydrant box: (1102, 541, 1126, 600)
#   Car box:     (446, 497, 510, 549)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=572
#   overlap_ratio=0.00
#
# Hydrant 0 vs Car 8:
#   Hydrant box: (1102, 541, 1126, 600)
#   Car box:     (449, 495, 530, 550)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=552
#   overlap_ratio=0.00
#
# Hydrant 0 vs Car 9:
#   Hydrant box: (1102, 541, 1126, 600)
#   Car box:     (445, 501, 491, 549)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=591
#   overlap_ratio=0.00
#
# Hydrant 0 vs Car 10:
#   Hydrant box: (1102, 541, 1126, 600)
#   Car box:     (177, 479, 266, 517)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=816
#   overlap_ratio=0.00
# ✅ Clear: 13.png
#
# Hydrant 0 vs Car 0:
#   Hydrant box: (1334, 599, 1381, 685)
#   Car box:     (705, 454, 989, 640)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=325
#   overlap_ratio=0.00
#
# Hydrant 0 vs Car 1:
#   Hydrant box: (1334, 599, 1381, 685)
#   Car box:     (443, 408, 748, 558)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=566
#   overlap_ratio=0.00
#
# Hydrant 0 vs Car 2:
#   Hydrant box: (1334, 599, 1381, 685)
#   Car box:     (205, 391, 457, 513)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=857
#   overlap_ratio=0.00
# ✅ Clear: 4.png
#
# Hydrant 0 vs Car 0:
#   Hydrant box: (922, 596, 948, 653)
#   Car box:     (150, 589, 405, 762)
#   horiz_frac=0.00, vertical_ok=True, prox_gap=497
#   overlap_ratio=0.00
#
# Hydrant 0 vs Car 1:
#   Hydrant box: (922, 596, 948, 653)
#   Car box:     (1316, 535, 1479, 649)
#   horiz_frac=0.00, vertical_ok=True, prox_gap=348
#   overlap_ratio=0.00
#
# Hydrant 0 vs Car 2:
#   Hydrant box: (922, 596, 948, 653)
#   Car box:     (1495, 478, 1565, 524)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=527
#   overlap_ratio=0.00
#
# Hydrant 0 vs Car 3:
#   Hydrant box: (922, 596, 948, 653)
#   Car box:     (1752, 485, 1885, 565)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=784
#   overlap_ratio=0.00
#
# Hydrant 0 vs Car 4:
#   Hydrant box: (922, 596, 948, 653)
#   Car box:     (40, 541, 147, 615)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=755
#   overlap_ratio=0.00
#
# Hydrant 0 vs Car 5:
#   Hydrant box: (922, 596, 948, 653)
#   Car box:     (99, 569, 267, 678)
#   horiz_frac=0.00, vertical_ok=True, prox_gap=635
#   overlap_ratio=0.00
#
# Hydrant 0 vs Car 6:
#   Hydrant box: (922, 596, 948, 653)
#   Car box:     (1709, 467, 1782, 518)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=741
#   overlap_ratio=0.00
#
# Hydrant 0 vs Car 7:
#   Hydrant box: (922, 596, 948, 653)
#   Car box:     (1548, 457, 1597, 497)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=580
#   overlap_ratio=0.00
#
# Hydrant 0 vs Car 8:
#   Hydrant box: (922, 596, 948, 653)
#   Car box:     (199, 493, 272, 537)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=630
#   overlap_ratio=0.00
#
# Hydrant 0 vs Car 9:
#   Hydrant box: (922, 596, 948, 653)
#   Car box:     (173, 491, 271, 535)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=631
#   overlap_ratio=0.00
#
# Hydrant 0 vs Car 10:
#   Hydrant box: (922, 596, 948, 653)
#   Car box:     (135, 474, 177, 501)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=725
#   overlap_ratio=0.00
#
# Hydrant 0 vs Car 11:
#   Hydrant box: (922, 596, 948, 653)
#   Car box:     (26, 498, 80, 553)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=822
#   overlap_ratio=0.00
# ✅ Clear: 22.png
# ✅ Clear: 18.png
# ✅ Clear: 10.png
#
# Hydrant 0 vs Car 0:
#   Hydrant box: (913, 517, 946, 600)
#   Car box:     (1153, 444, 1292, 546)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=187
#   overlap_ratio=0.00
#
# Hydrant 0 vs Car 1:
#   Hydrant box: (913, 517, 946, 600)
#   Car box:     (1688, 453, 1906, 561)
#   horiz_frac=0.00, vertical_ok=True, prox_gap=722
#   overlap_ratio=0.00
#
# Hydrant 0 vs Car 2:
#   Hydrant box: (913, 517, 946, 600)
#   Car box:     (1601, 432, 1772, 502)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=635
#   overlap_ratio=0.00
#
# Hydrant 0 vs Car 3:
#   Hydrant box: (913, 517, 946, 600)
#   Car box:     (1327, 396, 1366, 422)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=361
#   overlap_ratio=0.00
# ✅ Clear: 24.png
# ✅ Clear: 12.png
#
# Hydrant 0 vs Car 0:
#   Hydrant box: (1004, 470, 1037, 527)
#   Car box:     (1011, 477, 1904, 847)
#   horiz_frac=1.39, vertical_ok=True, prox_gap=46
#   overlap_ratio=0.00
# 🚨 Blocked: 96.png — hydrants [0]
# ✅ Clear: 21.png
#
# Hydrant 0 vs Car 0:
#   Hydrant box: (668, 491, 704, 594)
#   Car box:     (1209, 396, 1274, 441)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=485
#   overlap_ratio=0.00
# ✅ Clear: 9.png
#
# Hydrant 0 vs Car 0:
#   Hydrant box: (1182, 597, 1216, 665)
#   Car box:     (132, 486, 495, 719)
#   horiz_frac=0.00, vertical_ok=True, prox_gap=667
#   overlap_ratio=0.00
#
# Hydrant 0 vs Car 1:
#   Hydrant box: (1182, 597, 1216, 665)
#   Car box:     (482, 490, 592, 579)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=570
#   overlap_ratio=0.00
#
# Hydrant 0 vs Car 2:
#   Hydrant box: (1182, 597, 1216, 665)
#   Car box:     (1161, 479, 1407, 572)
#   horiz_frac=2.18, vertical_ok=False, prox_gap=75
#   overlap_ratio=0.00
#
# Hydrant 0 vs Car 3:
#   Hydrant box: (1182, 597, 1216, 665)
#   Car box:     (737, 431, 766, 459)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=396
#   overlap_ratio=0.00
#
# Hydrant 0 vs Car 4:
#   Hydrant box: (1182, 597, 1216, 665)
#   Car box:     (667, 459, 742, 529)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=420
#   overlap_ratio=0.00
#
# Hydrant 0 vs Car 5:
#   Hydrant box: (1182, 597, 1216, 665)
#   Car box:     (825, 453, 867, 491)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=295
#   overlap_ratio=0.00
# ✅ Clear: 17.png
#
# Hydrant 0 vs Car 0:
#   Hydrant box: (912, 432, 936, 489)
#   Car box:     (1505, 402, 1663, 490)
#   horiz_frac=0.00, vertical_ok=True, prox_gap=549
#   overlap_ratio=0.00
#
# Hydrant 0 vs Car 1:
#   Hydrant box: (912, 432, 936, 489)
#   Car box:     (403, 392, 534, 473)
#   horiz_frac=0.00, vertical_ok=True, prox_gap=358
#   overlap_ratio=0.00
#
# Hydrant 0 vs Car 2:
#   Hydrant box: (912, 432, 936, 489)
#   Car box:     (637, 355, 669, 380)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=223
#   overlap_ratio=0.00
#
# Hydrant 0 vs Car 3:
#   Hydrant box: (912, 432, 936, 489)
#   Car box:     (502, 381, 566, 435)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=326
#   overlap_ratio=0.00
#
# Hydrant 0 vs Car 4:
#   Hydrant box: (912, 432, 936, 489)
#   Car box:     (537, 368, 578, 400)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=314
#   overlap_ratio=0.00
#
# Hydrant 0 vs Car 5:
#   Hydrant box: (912, 432, 936, 489)
#   Car box:     (467, 346, 529, 377)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=363
#   overlap_ratio=0.00
#
# Hydrant 0 vs Car 6:
#   Hydrant box: (912, 432, 936, 489)
#   Car box:     (570, 342, 594, 362)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=298
#   overlap_ratio=0.00
#
# Hydrant 0 vs Car 7:
#   Hydrant box: (912, 432, 936, 489)
#   Car box:     (1480, 375, 1576, 430)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=524
#   overlap_ratio=0.00
#
# Hydrant 0 vs Car 8:
#   Hydrant box: (912, 432, 936, 489)
#   Car box:     (1246, 344, 1282, 367)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=290
#   overlap_ratio=0.00
#
# Hydrant 0 vs Car 9:
#   Hydrant box: (912, 432, 936, 489)
#   Car box:     (1450, 373, 1496, 417)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=494
#   overlap_ratio=0.00
#
# Hydrant 0 vs Car 10:
#   Hydrant box: (912, 432, 936, 489)
#   Car box:     (1463, 378, 1511, 425)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=507
#   overlap_ratio=0.00
#
# Hydrant 1 vs Car 0:
#   Hydrant box: (983, 429, 1006, 508)
#   Car box:     (1505, 402, 1663, 490)
#   horiz_frac=0.00, vertical_ok=True, prox_gap=479
#   overlap_ratio=0.00
#
# Hydrant 1 vs Car 1:
#   Hydrant box: (983, 429, 1006, 508)
#   Car box:     (403, 392, 534, 473)
#   horiz_frac=0.00, vertical_ok=True, prox_gap=429
#   overlap_ratio=0.00
#
# Hydrant 1 vs Car 2:
#   Hydrant box: (983, 429, 1006, 508)
#   Car box:     (637, 355, 669, 380)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=294
#   overlap_ratio=0.00
#
# Hydrant 1 vs Car 3:
#   Hydrant box: (983, 429, 1006, 508)
#   Car box:     (502, 381, 566, 435)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=397
#   overlap_ratio=0.00
#
# Hydrant 1 vs Car 4:
#   Hydrant box: (983, 429, 1006, 508)
#   Car box:     (537, 368, 578, 400)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=385
#   overlap_ratio=0.00
#
# Hydrant 1 vs Car 5:
#   Hydrant box: (983, 429, 1006, 508)
#   Car box:     (467, 346, 529, 377)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=434
#   overlap_ratio=0.00
#
# Hydrant 1 vs Car 6:
#   Hydrant box: (983, 429, 1006, 508)
#   Car box:     (570, 342, 594, 362)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=369
#   overlap_ratio=0.00
#
# Hydrant 1 vs Car 7:
#   Hydrant box: (983, 429, 1006, 508)
#   Car box:     (1480, 375, 1576, 430)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=454
#   overlap_ratio=0.00
#
# Hydrant 1 vs Car 8:
#   Hydrant box: (983, 429, 1006, 508)
#   Car box:     (1246, 344, 1282, 367)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=220
#   overlap_ratio=0.00
#
# Hydrant 1 vs Car 9:
#   Hydrant box: (983, 429, 1006, 508)
#   Car box:     (1450, 373, 1496, 417)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=424
#   overlap_ratio=0.00
#
# Hydrant 1 vs Car 10:
#   Hydrant box: (983, 429, 1006, 508)
#   Car box:     (1463, 378, 1511, 425)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=437
#   overlap_ratio=0.00
# ✅ Clear: 1.png
#
# Hydrant 0 vs Car 0:
#   Hydrant box: (1211, 591, 1246, 677)
#   Car box:     (839, 507, 882, 545)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=309
#   overlap_ratio=0.00
#
# Hydrant 0 vs Car 1:
#   Hydrant box: (1211, 591, 1246, 677)
#   Car box:     (10, 791, 462, 912)
#   horiz_frac=0.00, vertical_ok=True, prox_gap=729
#   overlap_ratio=0.00
#
# Hydrant 0 vs Car 2:
#   Hydrant box: (1211, 591, 1246, 677)
#   Car box:     (909, 497, 937, 530)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=254
#   overlap_ratio=0.00
# ✅ Clear: 14.png
#
# Hydrant 0 vs Car 0:
#   Hydrant box: (756, 610, 779, 665)
#   Car box:     (1478, 715, 1910, 908)
#   horiz_frac=0.00, vertical_ok=True, prox_gap=679
#   overlap_ratio=0.00
#
# Hydrant 0 vs Car 1:
#   Hydrant box: (756, 610, 779, 665)
#   Car box:     (1234, 603, 1519, 741)
#   horiz_frac=0.00, vertical_ok=True, prox_gap=435
#   overlap_ratio=0.00
#
# Hydrant 0 vs Car 2:
#   Hydrant box: (756, 610, 779, 665)
#   Car box:     (1105, 548, 1164, 591)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=306
#   overlap_ratio=0.00
#
# Hydrant 0 vs Car 3:
#   Hydrant box: (756, 610, 779, 665)
#   Car box:     (1020, 526, 1078, 552)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=221
#   overlap_ratio=0.00
#
# Hydrant 0 vs Car 4:
#   Hydrant box: (756, 610, 779, 665)
#   Car box:     (979, 536, 1017, 570)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=180
#   overlap_ratio=0.00
# ✅ Clear: 19.png
# ✅ Clear: 6.png
#
# Hydrant 0 vs Car 0:
#   Hydrant box: (523, 584, 558, 687)
#   Car box:     (727, 499, 839, 601)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=149
#   overlap_ratio=0.00
#
# Hydrant 0 vs Car 1:
#   Hydrant box: (523, 584, 558, 687)
#   Car box:     (1087, 508, 1255, 642)
#   horiz_frac=0.00, vertical_ok=True, prox_gap=509
#   overlap_ratio=0.00
#
# Hydrant 0 vs Car 2:
#   Hydrant box: (523, 584, 558, 687)
#   Car box:     (995, 489, 1059, 537)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=417
#   overlap_ratio=0.00
#
# Hydrant 0 vs Car 3:
#   Hydrant box: (523, 584, 558, 687)
#   Car box:     (810, 476, 873, 527)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=232
#   overlap_ratio=0.00
#
# Hydrant 0 vs Car 4:
#   Hydrant box: (523, 584, 558, 687)
#   Car box:     (1047, 504, 1105, 593)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=469
#   overlap_ratio=0.00
#
# Hydrant 0 vs Car 5:
#   Hydrant box: (523, 584, 558, 687)
#   Car box:     (1048, 505, 1141, 595)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=470
#   overlap_ratio=0.00
# ✅ Clear: 16.png
#
# Hydrant 0 vs Car 0:
#   Hydrant box: (1131, 594, 1162, 652)
#   Car box:     (393, 503, 554, 606)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=557
#   overlap_ratio=0.00
#
# Hydrant 0 vs Car 1:
#   Hydrant box: (1131, 594, 1162, 652)
#   Car box:     (0, 504, 102, 622)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=1009
#   overlap_ratio=0.00
#
# Hydrant 0 vs Car 2:
#   Hydrant box: (1131, 594, 1162, 652)
#   Car box:     (619, 486, 682, 530)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=429
#   overlap_ratio=0.00
#
# Hydrant 0 vs Car 3:
#   Hydrant box: (1131, 594, 1162, 652)
#   Car box:     (678, 479, 720, 510)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=391
#   overlap_ratio=0.00
#
# Hydrant 0 vs Car 4:
#   Hydrant box: (1131, 594, 1162, 652)
#   Car box:     (768, 484, 826, 537)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=285
#   overlap_ratio=0.00
#
# Hydrant 0 vs Car 5:
#   Hydrant box: (1131, 594, 1162, 652)
#   Car box:     (850, 495, 886, 528)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=225
#   overlap_ratio=0.00
#
# Hydrant 0 vs Car 6:
#   Hydrant box: (1131, 594, 1162, 652)
#   Car box:     (1278, 489, 1395, 541)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=96
#   overlap_ratio=0.00
#
# Hydrant 0 vs Car 7:
#   Hydrant box: (1131, 594, 1162, 652)
#   Car box:     (738, 463, 780, 489)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=331
#   overlap_ratio=0.00
#
# Hydrant 0 vs Car 8:
#   Hydrant box: (1131, 594, 1162, 652)
#   Car box:     (711, 478, 738, 507)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=373
#   overlap_ratio=0.00
#
# Hydrant 0 vs Car 9:
#   Hydrant box: (1131, 594, 1162, 652)
#   Car box:     (854, 492, 909, 529)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=202
#   overlap_ratio=0.00
#
# Hydrant 0 vs Car 10:
#   Hydrant box: (1131, 594, 1162, 652)
#   Car box:     (828, 478, 857, 501)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=254
#   overlap_ratio=0.00
# ✅ Clear: 23.png
# ✅ Clear: 20.png
#
# Hydrant 0 vs Car 0:
#   Hydrant box: (996, 545, 1025, 609)
#   Car box:     (0, 573, 299, 854)
#   horiz_frac=0.00, vertical_ok=True, prox_gap=677
#   overlap_ratio=0.00
#
# Hydrant 0 vs Car 1:
#   Hydrant box: (996, 545, 1025, 609)
#   Car box:     (685, 461, 766, 517)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=210
#   overlap_ratio=0.00
#
# Hydrant 0 vs Car 2:
#   Hydrant box: (996, 545, 1025, 609)
#   Car box:     (1683, 464, 1909, 597)
#   horiz_frac=0.00, vertical_ok=True, prox_gap=638
#   overlap_ratio=0.00
#
# Hydrant 0 vs Car 3:
#   Hydrant box: (996, 545, 1025, 609)
#   Car box:     (325, 466, 448, 550)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=528
#   overlap_ratio=0.00
#
# Hydrant 0 vs Car 4:
#   Hydrant box: (996, 545, 1025, 609)
#   Car box:     (397, 444, 492, 510)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=484
#   overlap_ratio=0.00
#
# Hydrant 0 vs Car 5:
#   Hydrant box: (996, 545, 1025, 609)
#   Car box:     (520, 440, 562, 471)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=414
#   overlap_ratio=0.00
#
# Hydrant 0 vs Car 6:
#   Hydrant box: (996, 545, 1025, 609)
#   Car box:     (675, 457, 712, 493)
#   horiz_frac=0.00, vertical_ok=False, prox_gap=264
#   overlap_ratio=0.00
# ✅ Clear: 11.png
#
# Hydrant 0 vs Car 0:
#   Hydrant box: (962, 454, 986, 511)
#   Car box:     (923, 497, 1356, 739)
#   horiz_frac=2.67, vertical_ok=True, prox_gap=83
#   overlap_ratio=0.00
# 🚨 Blocked: 8.png — hydrants [0]

# %%
import cv2
import numpy as np
import os
from ultralytics import YOLO

# ---------------- Config ----------------
INPUT_FOLDER = "/content/hydrant_pano_images"
OUTPUT_FOLDER = "/content/result_out"

COVER_FRAC = 0.25          # % hydrant covered by car
FOREGROUND_Y_MARGIN = 10   # pixels, car centroid must be below hydrant centroid

# Class IDs (⚠️ adjust these to your trained model’s IDs)
HYDRANT_CLASS = 10  # change if hydrant is not class 10
CAR_CLASS = 2       # change if car is not class 2

os.makedirs(OUTPUT_FOLDER, exist_ok=True)


# ---------------- Utils ----------------
def get_box_and_mask(result, class_id):
    """Extract bounding boxes & masks for a given class_id."""
    objects = []
    masks = result.masks.data.cpu().numpy().astype(bool) if result.masks is not None else [None] * len(result.boxes)

    for i, box in enumerate(result.boxes):
        cls = int(box.cls)
        if cls != class_id:
            continue
        x1, y1, x2, y2 = map(int, box.xyxy[0].cpu().numpy())
        centroid = ((y1 + y2) // 2, (x1 + x2) // 2)
        mask = masks[i] if masks[i] is not None else None
        objects.append({
            "box": (x1, y1, x2, y2),
            "mask": mask,
            "centroid": centroid
        })
    return objects


def hydrant_blocked(hydrants, cars, use_masks=True, cover_thresh=0.15, horiz_thresh=0.3, prox_thresh=30):
    """Determine if hydrants are blocked by cars."""
    results = [False] * len(hydrants)

    for hi, h in enumerate(hydrants):
        hx1, hy1, hx2, hy2 = h["box"]
        h_w, h_h = hx2 - hx1, hy2 - hy1
        h_cy = (hy1 + hy2) / 2
        pad = 20
        hx1e, hy1e, hx2e, hy2e = hx1 - pad, hy1 - pad, hx2 + pad, hy2 + pad

        for c in cars:
            cx1, cy1, cx2, cy2 = c["box"]
            blocked = False
            vertical_ok = cy2 >= h_cy

            # Mask overlap check
            if use_masks and h.get("mask") is not None and c.get("mask") is not None:
                h_mask = h["mask"].astype(np.uint8)
                c_mask = c["mask"].astype(np.uint8)
                inter = cv2.bitwise_and(h_mask, c_mask)
                overlap_ratio = inter.sum() / (h_mask.sum() + 1e-6)
                if overlap_ratio >= cover_thresh:
                    blocked = True

            # Bounding box overlap fallback
            if not blocked:
                overlap_w = max(0, min(hx2e, cx2) - max(hx1e, cx1))
                horiz_frac = overlap_w / (h_w + 1e-6)
                horiz_gap = min(abs(cx1 - hx2e), abs(hx1e - cx2))
                if (horiz_frac >= horiz_thresh and vertical_ok) or (horiz_gap <= prox_thresh and vertical_ok):
                    blocked = True

            if blocked:
                results[hi] = True
                break

    return results


def draw_overlay(img, hydrants, cars, blocked_status):
    """Draw results on image."""
    out = img.copy()

    # Draw cars
    for c in cars:
        x1, y1, x2, y2 = c["box"]
        cv2.rectangle(out, (x1, y1), (x2, y2), (0, 255, 0), 2)
        cv2.putText(out, "Car", (x1, y1 - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

    # Draw hydrants
    for idx, (h, blocked) in enumerate(zip(hydrants, blocked_status)):
        x1, y1, x2, y2 = h["box"]
        color = (0, 0, 255) if blocked else (255, 0, 0)
        label = f"Hydrant {idx} BLOCKED" if blocked else f"Hydrant {idx} CLEAR"
        cv2.rectangle(out, (x1, y1), (x2, y2), color, 2)
        cv2.putText(out, label, (x1, y1 - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)

    return out


# ---------------- Main ----------------
def process_image(model, img_path):
    """Run detection and overlay for a single image."""
    img = cv2.imread(img_path)
    if img is None:
        raise ValueError(f"Could not load {img_path}")

    results = model.predict(img, verbose=False)[0]

    hydrants = get_box_and_mask(results, HYDRANT_CLASS)
    cars = get_box_and_mask(results, CAR_CLASS)

    blocked_status = hydrant_blocked(hydrants, cars)
    out = draw_overlay(img, hydrants, cars, blocked_status)

    return out, blocked_status


if __name__ == "__main__":
    # Load YOLO model
    model = YOLO("yolov8s.pt")  # Change path if needed

    for img_file in os.listdir(INPUT_FOLDER):
        if not img_file.lower().endswith((".jpg", ".png", ".jpeg")):
            continue

        img_path = os.path.join(INPUT_FOLDER, img_file)
        out, status = process_image(model, img_path)

        blocked_ids = [i for i, b in enumerate(status) if b]
        if blocked_ids:
            print(f"🚨 Blocked: {img_file} — hydrants {blocked_ids}")
        else:
            print(f"✅ Clear: {img_file}")

        # Save overlay
        out_path = os.path.join(OUTPUT_FOLDER, img_file)
        cv2.imwrite(out_path, out)
# Out:
# ✅ Clear: 25.png
# ✅ Clear: 7.png
# ✅ Clear: 5.png
# ✅ Clear: 15.png
# ✅ Clear: 13.png
# ✅ Clear: 4.png
# ✅ Clear: 22.png
# ✅ Clear: 18.png
# ✅ Clear: 10.png
# ✅ Clear: 24.png
# ✅ Clear: 12.png
# 🚨 Blocked: 96.png — hydrants [0]
# ✅ Clear: 21.png
# ✅ Clear: 9.png
# ✅ Clear: 17.png
# ✅ Clear: 1.png
# ✅ Clear: 14.png
# ✅ Clear: 19.png
# ✅ Clear: 6.png
# ✅ Clear: 16.png
# ✅ Clear: 23.png
# ✅ Clear: 20.png
# ✅ Clear: 11.png
# 🚨 Blocked: 8.png — hydrants [0]
